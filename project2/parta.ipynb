# %% [markdown]
# <a href="https://colab.research.google.com/github/xmrcl0/7600064/blob/main/project2/parta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2

# %% [markdown]
# ## Part A
# Read the Iris data set and view the groups in all combinations of 2
# between the 4 attributes. Each group must be marked with a respective color, and the scatterplots must include a legend for the colors and / or marks. Apply k-neighbors in these 2-by-2 configurations, reserving 25 cases from each category for training and 25 for testing. Obtain, present and briefly discuss the performance for each configuration of attributes using the respective confusion matrices, which also need to be presented.

# %%
# Load 
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Plot 
g = sns.pairplot(iris, vars=["sepal_width",
                             "sepal_length",
                             "petal_length",
                             "petal_width"], hue='species', height=3)
